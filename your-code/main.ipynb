# %% [markdown]
# # Import and Export Files

# %% [markdown]
# # Challenge 0 - Accessing our database
# Create a connection to access the sakila database with the ip, user and password provided in class. Take a look at the data. Do some joins in order to have more elaborated tables in a dataframe (you can try first the query in the DBMS and then use it in your notebook).

# %%
# your code here
import mysql.connector
import pandas as pd

# %%
cnx= mysql.connector.connect(user = 'userpt', password = 'Openplz00', host = '127.0.0.1')
cnx.is_connected()
# Out:
# True

# %%
cursor = cnx.cursor()

# %%
query = """SELECT rental_date, return_date, first_name, last_name
FROM sakila.rental
INNER JOIN  sakila.staff
ON rental.staff_id = staff.staff_id"""

# %%
cursor.execute(query)

# %%
result = cursor.fetchall()
result
# Out:
# [(datetime.datetime(2005, 5, 24, 22, 53, 30),
#   datetime.datetime(2005, 5, 26, 22, 4, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 24, 22, 54, 33),
#   datetime.datetime(2005, 5, 28, 19, 40, 33),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 24, 23, 3, 39),
#   datetime.datetime(2005, 6, 1, 22, 12, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 24, 23, 5, 21),
#   datetime.datetime(2005, 6, 2, 4, 33, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 24, 23, 8, 7),
#   datetime.datetime(2005, 5, 27, 1, 32, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 0, 0, 40),
#   datetime.datetime(2005, 5, 28, 0, 22, 40),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 0, 22, 55),
#   datetime.datetime(2005, 5, 30, 4, 28, 55),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 0, 31, 15),
#   datetime.datetime(2005, 5, 26, 2, 56, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 0, 39, 22),
#   datetime.datetime(2005, 6, 3, 3, 30, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 1, 6, 36),
#   datetime.datetime(2005, 5, 27, 0, 43, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 1, 17, 24),
#   datetime.datetime(2005, 5, 31, 6, 0, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 2, 40, 21),
#   datetime.datetime(2005, 5, 29, 6, 34, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 2, 53, 2),
#   datetime.datetime(2005, 5, 27, 1, 15, 2),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 3, 36, 50),
#   datetime.datetime(2005, 5, 31, 0, 34, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 4, 1, 32),
#   datetime.datetime(2005, 5, 30, 3, 12, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 4, 5, 17),
#   datetime.datetime(2005, 5, 30, 7, 15, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 4, 6, 21),
#   datetime.datetime(2005, 5, 25, 23, 55, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 4, 18, 51),
#   datetime.datetime(2005, 5, 27, 3, 58, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 4, 36, 26),
#   datetime.datetime(2005, 5, 29, 0, 31, 26),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 4, 44, 31),
#   datetime.datetime(2005, 5, 29, 1, 3, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 4, 47, 44),
#   datetime.datetime(2005, 6, 1, 0, 58, 44),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 5, 9, 4),
#   datetime.datetime(2005, 5, 27, 23, 12, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 5, 12, 29),
#   datetime.datetime(2005, 6, 2, 0, 28, 29),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 6, 5, 20),
#   datetime.datetime(2005, 5, 30, 3, 4, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 6, 20, 46),
#   datetime.datetime(2005, 6, 2, 5, 42, 46),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 6, 49, 10),
#   datetime.datetime(2005, 5, 26, 6, 42, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 8, 26, 13),
#   datetime.datetime(2005, 5, 30, 10, 57, 13),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 8, 28, 11),
#   datetime.datetime(2005, 5, 26, 14, 21, 11),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 8, 53, 14),
#   datetime.datetime(2005, 5, 28, 14, 40, 14),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 8, 56, 42),
#   datetime.datetime(2005, 6, 1, 9, 52, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 8, 58, 25),
#   datetime.datetime(2005, 5, 30, 14, 14, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 9, 18, 52),
#   datetime.datetime(2005, 5, 30, 10, 55, 52),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 9, 19, 16),
#   datetime.datetime(2005, 5, 27, 4, 24, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 9, 21, 29),
#   datetime.datetime(2005, 6, 3, 11, 31, 29),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 9, 32, 3),
#   datetime.datetime(2005, 5, 29, 14, 21, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 10, 26, 39),
#   datetime.datetime(2005, 5, 28, 4, 59, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 11, 13, 34),
#   datetime.datetime(2005, 6, 3, 12, 58, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 12, 17, 46),
#   datetime.datetime(2005, 6, 1, 10, 48, 46),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 12, 30, 15),
#   datetime.datetime(2005, 5, 27, 15, 40, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 12, 36, 30),
#   datetime.datetime(2005, 5, 29, 18, 33, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 13, 5, 34),
#   datetime.datetime(2005, 5, 29, 16, 53, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 13, 36, 12),
#   datetime.datetime(2005, 5, 30, 14, 53, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 14, 28, 29),
#   datetime.datetime(2005, 5, 29, 14, 33, 29),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 14, 31, 25),
#   datetime.datetime(2005, 6, 1, 10, 7, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 14, 57, 22),
#   datetime.datetime(2005, 6, 1, 18, 32, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 15, 54, 16),
#   datetime.datetime(2005, 6, 3, 20, 18, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 16, 3, 42),
#   datetime.datetime(2005, 5, 30, 14, 23, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 16, 50, 20),
#   datetime.datetime(2005, 5, 28, 18, 52, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 16, 50, 28),
#   datetime.datetime(2005, 6, 2, 22, 11, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 17, 17, 4),
#   datetime.datetime(2005, 5, 31, 19, 47, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 17, 22, 10),
#   datetime.datetime(2005, 5, 31, 19, 47, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 17, 30, 42),
#   datetime.datetime(2005, 6, 3, 22, 36, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 17, 46, 33),
#   datetime.datetime(2005, 5, 27, 15, 20, 33),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 18, 30, 5),
#   datetime.datetime(2005, 5, 30, 19, 40, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 18, 45, 19),
#   datetime.datetime(2005, 5, 28, 17, 18, 19),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 18, 57, 24),
#   datetime.datetime(2005, 6, 2, 20, 44, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 19, 12, 42),
#   datetime.datetime(2005, 6, 1, 23, 10, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 19, 13, 25),
#   datetime.datetime(2005, 5, 29, 20, 17, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 19, 27, 51),
#   datetime.datetime(2005, 5, 26, 16, 23, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 19, 31, 18),
#   datetime.datetime(2005, 5, 31, 15, 0, 18),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 19, 41, 29),
#   datetime.datetime(2005, 5, 29, 21, 31, 29),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 19, 46, 21),
#   datetime.datetime(2005, 6, 2, 19, 7, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 20, 26, 42),
#   datetime.datetime(2005, 5, 26, 19, 41, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 20, 48, 50),
#   datetime.datetime(2005, 6, 2, 21, 39, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 21, 7, 59),
#   datetime.datetime(2005, 5, 28, 18, 51, 59),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 21, 10, 40),
#   datetime.datetime(2005, 6, 2, 21, 38, 40),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 21, 19, 53),
#   datetime.datetime(2005, 5, 29, 23, 34, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 21, 46, 54),
#   datetime.datetime(2005, 5, 31, 21, 2, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 21, 48, 41),
#   datetime.datetime(2005, 6, 2, 18, 28, 41),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 21, 58, 58),
#   datetime.datetime(2005, 6, 3, 17, 50, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 22, 2, 30),
#   datetime.datetime(2005, 5, 31, 18, 6, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 23, 0, 21),
#   datetime.datetime(2005, 5, 29, 17, 12, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 23, 34, 22),
#   datetime.datetime(2005, 5, 27, 1, 10, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 23, 34, 53),
#   datetime.datetime(2005, 6, 2, 1, 57, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 25, 23, 59, 3),
#   datetime.datetime(2005, 5, 31, 2, 56, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 0, 37, 28),
#   datetime.datetime(2005, 5, 30, 6, 28, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 0, 41, 10),
#   datetime.datetime(2005, 6, 3, 6, 5, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 0, 47, 47),
#   datetime.datetime(2005, 5, 27, 21, 28, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 1, 15, 5),
#   datetime.datetime(2005, 6, 1, 0, 3, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 1, 19, 5),
#   datetime.datetime(2005, 5, 27, 23, 43, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 1, 34, 28),
#   datetime.datetime(2005, 5, 29, 4, 0, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 1, 46, 20),
#   datetime.datetime(2005, 6, 1, 5, 45, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 1, 51, 48),
#   datetime.datetime(2005, 5, 27, 5, 42, 48),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 2, 26, 23),
#   datetime.datetime(2005, 6, 4, 6, 36, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 2, 26, 49),
#   datetime.datetime(2005, 5, 28, 0, 32, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 2, 28, 36),
#   datetime.datetime(2005, 6, 2, 3, 21, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 2, 49, 11),
#   datetime.datetime(2005, 5, 31, 1, 28, 11),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 2, 50, 31),
#   datetime.datetime(2005, 5, 27, 3, 7, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 3, 11, 12),
#   datetime.datetime(2005, 6, 2, 3, 53, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 4, 26, 6),
#   datetime.datetime(2005, 6, 3, 10, 6, 6),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 4, 46, 23),
#   datetime.datetime(2005, 6, 1, 9, 58, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 5, 1, 18),
#   datetime.datetime(2005, 6, 1, 9, 4, 18),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 5, 29, 49),
#   datetime.datetime(2005, 5, 28, 10, 10, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 5, 42, 37),
#   datetime.datetime(2005, 6, 4, 0, 38, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 5, 47, 12),
#   datetime.datetime(2005, 5, 26, 23, 48, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 6, 1, 41),
#   datetime.datetime(2005, 5, 27, 6, 11, 41),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 6, 11, 28),
#   datetime.datetime(2005, 6, 1, 9, 44, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 6, 14, 6),
#   datetime.datetime(2005, 5, 28, 5, 33, 6),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 6, 20, 37),
#   datetime.datetime(2005, 6, 2, 10, 57, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 6, 55, 58),
#   datetime.datetime(2005, 5, 27, 10, 54, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 7, 3, 49),
#   datetime.datetime(2005, 6, 4, 11, 45, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 7, 11, 58),
#   datetime.datetime(2005, 5, 28, 9, 6, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 7, 12, 21),
#   datetime.datetime(2005, 5, 31, 12, 7, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 7, 27, 36),
#   datetime.datetime(2005, 6, 2, 3, 52, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 7, 27, 57),
#   datetime.datetime(2005, 6, 3, 12, 52, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 7, 30, 37),
#   datetime.datetime(2005, 5, 30, 8, 11, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 8, 1, 54),
#   datetime.datetime(2005, 5, 27, 6, 26, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 8, 10, 22),
#   datetime.datetime(2005, 5, 27, 3, 55, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 8, 14, 1),
#   datetime.datetime(2005, 5, 27, 9, 0, 1),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 8, 33, 10),
#   datetime.datetime(2005, 5, 28, 14, 9, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 9, 17, 43),
#   datetime.datetime(2005, 6, 3, 8, 21, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 9, 41, 45),
#   datetime.datetime(2005, 5, 28, 4, 40, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 10, 6, 49),
#   datetime.datetime(2005, 6, 1, 7, 43, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 10, 14, 9),
#   datetime.datetime(2005, 5, 29, 5, 57, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 10, 15, 23),
#   datetime.datetime(2005, 5, 30, 11, 43, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 10, 18, 27),
#   datetime.datetime(2005, 6, 4, 6, 59, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 10, 51, 46),
#   datetime.datetime(2005, 5, 30, 7, 24, 46),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 10, 54, 28),
#   datetime.datetime(2005, 6, 4, 9, 39, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 11, 31, 50),
#   datetime.datetime(2005, 5, 30, 15, 22, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 11, 31, 59),
#   datetime.datetime(2005, 5, 27, 7, 27, 59),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 11, 51, 9),
#   datetime.datetime(2005, 6, 4, 9, 36, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 11, 53, 49),
#   datetime.datetime(2005, 5, 28, 13, 55, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 12, 15, 13),
#   datetime.datetime(2005, 5, 29, 18, 10, 13),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 12, 30, 22),
#   datetime.datetime(2005, 5, 27, 6, 49, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 12, 40, 23),
#   datetime.datetime(2005, 6, 4, 7, 22, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 13, 5, 8),
#   datetime.datetime(2005, 6, 2, 15, 26, 8),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 13, 40, 40),
#   datetime.datetime(2005, 5, 31, 11, 58, 40),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 14, 30, 24),
#   datetime.datetime(2005, 5, 27, 8, 50, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 14, 35, 40),
#   datetime.datetime(2005, 5, 29, 17, 17, 40),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 14, 39, 53),
#   datetime.datetime(2005, 6, 2, 14, 48, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 14, 43, 14),
#   datetime.datetime(2005, 5, 27, 12, 21, 14),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 14, 52, 15),
#   datetime.datetime(2005, 5, 27, 12, 45, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 15, 20, 58),
#   datetime.datetime(2005, 5, 31, 15, 58, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 16, 7, 38),
#   datetime.datetime(2005, 6, 1, 14, 20, 38),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 16, 19, 8),
#   datetime.datetime(2005, 5, 27, 14, 35, 8),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 16, 48, 51),
#   datetime.datetime(2005, 6, 3, 18, 17, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 17, 9, 53),
#   datetime.datetime(2005, 6, 4, 22, 35, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 17, 16, 7),
#   datetime.datetime(2005, 6, 3, 12, 59, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 17, 32, 11),
#   datetime.datetime(2005, 5, 28, 22, 54, 11),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 18, 36, 58),
#   datetime.datetime(2005, 5, 27, 23, 42, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 19, 5, 5),
#   datetime.datetime(2005, 5, 31, 19, 19, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 19, 44, 54),
#   datetime.datetime(2005, 6, 2, 1, 10, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 20, 1, 9),
#   datetime.datetime(2005, 5, 28, 15, 9, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 20, 8, 33),
#   datetime.datetime(2005, 5, 30, 0, 32, 33),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 20, 22, 12),
#   datetime.datetime(2005, 6, 5, 0, 58, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 20, 29, 57),
#   datetime.datetime(2005, 5, 28, 17, 20, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 21, 21, 28),
#   datetime.datetime(2005, 6, 2, 0, 5, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 21, 31, 57),
#   datetime.datetime(2005, 5, 28, 19, 37, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 21, 48, 13),
#   datetime.datetime(2005, 6, 4, 22, 24, 13),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 22, 41, 7),
#   datetime.datetime(2005, 6, 2, 4, 9, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 22, 51, 37),
#   datetime.datetime(2005, 6, 1, 0, 2, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 23, 12, 55),
#   datetime.datetime(2005, 5, 29, 23, 33, 55),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 26, 23, 52, 13),
#   datetime.datetime(2005, 5, 30, 18, 55, 13),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 0, 47, 35),
#   datetime.datetime(2005, 6, 2, 0, 32, 35),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 0, 49, 27),
#   datetime.datetime(2005, 5, 30, 3, 12, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 1, 0, 4),
#   datetime.datetime(2005, 5, 30, 4, 27, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 1, 18, 57),
#   datetime.datetime(2005, 6, 4, 4, 6, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 1, 29, 31),
#   datetime.datetime(2005, 6, 1, 2, 27, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 2, 22, 26),
#   datetime.datetime(2005, 6, 5, 0, 25, 26),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 3, 3, 7),
#   datetime.datetime(2005, 5, 29, 3, 54, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 3, 15, 23),
#   datetime.datetime(2005, 5, 29, 22, 43, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 3, 22, 30),
#   datetime.datetime(2005, 6, 2, 3, 27, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 4, 1, 42),
#   datetime.datetime(2005, 6, 5, 8, 51, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 4, 13, 41),
#   datetime.datetime(2005, 5, 28, 8, 34, 41),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 4, 32, 25),
#   datetime.datetime(2005, 5, 31, 9, 50, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 4, 50, 56),
#   datetime.datetime(2005, 6, 1, 4, 43, 56),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 5, 39, 3),
#   datetime.datetime(2005, 6, 1, 11, 10, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 5, 48, 19),
#   datetime.datetime(2005, 5, 29, 9, 5, 19),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 6, 12, 26),
#   datetime.datetime(2005, 6, 1, 6, 48, 26),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 6, 48, 33),
#   datetime.datetime(2005, 5, 29, 3, 55, 33),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 6, 51, 14),
#   datetime.datetime(2005, 6, 3, 1, 58, 14),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 7, 3, 28),
#   datetime.datetime(2005, 5, 31, 8, 1, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 7, 10, 25),
#   datetime.datetime(2005, 6, 1, 8, 34, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 7, 31, 20),
#   datetime.datetime(2005, 6, 4, 4, 46, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 8, 16, 25),
#   datetime.datetime(2005, 6, 1, 11, 41, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 8, 26, 30),
#   datetime.datetime(2005, 6, 5, 7, 13, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 8, 49, 21),
#   datetime.datetime(2005, 6, 4, 14, 11, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 8, 58, 15),
#   datetime.datetime(2005, 6, 2, 4, 48, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 9, 23, 22),
#   datetime.datetime(2005, 5, 29, 15, 20, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 9, 25, 32),
#   datetime.datetime(2005, 6, 2, 6, 19, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 9, 34, 39),
#   datetime.datetime(2005, 6, 4, 11, 45, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 9, 43, 25),
#   datetime.datetime(2005, 5, 31, 12, 0, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 10, 12),
#   datetime.datetime(2005, 5, 31, 15, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 10, 12, 20),
#   datetime.datetime(2005, 6, 3, 10, 37, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 10, 26, 31),
#   datetime.datetime(2005, 5, 30, 8, 32, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 10, 37, 27),
#   datetime.datetime(2005, 5, 30, 5, 45, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 11, 45, 49),
#   datetime.datetime(2005, 5, 31, 13, 42, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 11, 47, 4),
#   datetime.datetime(2005, 5, 29, 10, 14, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 12, 44, 3),
#   datetime.datetime(2005, 6, 2, 8, 19, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 12, 48, 38),
#   datetime.datetime(2005, 5, 29, 15, 27, 38),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 13, 31, 51),
#   datetime.datetime(2005, 5, 30, 16, 58, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 13, 46, 46),
#   datetime.datetime(2005, 5, 30, 12, 43, 46),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 13, 57, 38),
#   datetime.datetime(2005, 5, 31, 18, 23, 38),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 13, 57, 39),
#   datetime.datetime(2005, 5, 28, 11, 57, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 14, 14, 14),
#   datetime.datetime(2005, 6, 3, 17, 39, 14),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 14, 45, 37),
#   datetime.datetime(2005, 6, 3, 11, 11, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 15, 15, 11),
#   datetime.datetime(2005, 6, 2, 11, 53, 11),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 15, 32, 57),
#   datetime.datetime(2005, 6, 2, 19, 3, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 15, 34, 1),
#   datetime.datetime(2005, 6, 5, 9, 44, 1),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 15, 56, 57),
#   datetime.datetime(2005, 6, 5, 11, 45, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 16, 22, 10),
#   datetime.datetime(2005, 6, 5, 13, 10, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 16, 31, 5),
#   datetime.datetime(2005, 6, 5, 11, 29, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 16, 40, 29),
#   datetime.datetime(2005, 5, 29, 16, 20, 29),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 16, 54, 27),
#   datetime.datetime(2005, 6, 4, 22, 26, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 18, 0, 35),
#   datetime.datetime(2005, 5, 29, 16, 15, 35),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 18, 11, 5),
#   datetime.datetime(2005, 5, 30, 22, 45, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 18, 35, 20),
#   datetime.datetime(2005, 6, 4, 18, 58, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 18, 39, 15),
#   datetime.datetime(2005, 6, 1, 15, 56, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 18, 57, 2),
#   datetime.datetime(2005, 6, 5, 18, 38, 2),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 19, 18, 54),
#   datetime.datetime(2005, 6, 5, 23, 52, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 19, 31, 16),
#   datetime.datetime(2005, 5, 29, 23, 6, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 19, 31, 36),
#   datetime.datetime(2005, 5, 30, 15, 46, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 19, 50, 6),
#   datetime.datetime(2005, 6, 2, 22, 14, 6),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 19, 58, 36),
#   datetime.datetime(2005, 6, 6, 0, 51, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 20, 0, 4),
#   datetime.datetime(2005, 5, 29, 22, 47, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 20, 2, 3),
#   datetime.datetime(2005, 5, 28, 16, 14, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 20, 8, 55),
#   datetime.datetime(2005, 6, 1, 14, 32, 55),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 20, 11, 47),
#   datetime.datetime(2005, 6, 4, 21, 18, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 20, 44, 36),
#   datetime.datetime(2005, 6, 2, 2, 43, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 20, 57, 7),
#   datetime.datetime(2005, 5, 29, 15, 52, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 21, 10, 3),
#   datetime.datetime(2005, 6, 1, 16, 8, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 21, 14, 26),
#   datetime.datetime(2005, 6, 5, 21, 51, 26),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 21, 17, 8),
#   datetime.datetime(2005, 6, 4, 17, 47, 8),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 21, 36, 15),
#   datetime.datetime(2005, 5, 29, 21, 7, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 21, 36, 34),
#   datetime.datetime(2005, 6, 5, 17, 2, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 22, 11, 56),
#   datetime.datetime(2005, 5, 31, 19, 7, 56),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 22, 16, 26),
#   datetime.datetime(2005, 5, 28, 19, 58, 26),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 22, 31, 36),
#   datetime.datetime(2005, 6, 3, 19, 12, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 23, 0, 25),
#   datetime.datetime(2005, 5, 28, 21, 30, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 27, 23, 51, 12),
#   datetime.datetime(2005, 5, 28, 20, 26, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 0, 24, 58),
#   datetime.datetime(2005, 5, 28, 22, 34, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 0, 34, 11),
#   datetime.datetime(2005, 5, 30, 18, 40, 11),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 0, 39, 31),
#   datetime.datetime(2005, 6, 2, 19, 35, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 0, 40, 48),
#   datetime.datetime(2005, 5, 29, 6, 7, 48),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 0, 43, 41),
#   datetime.datetime(2005, 6, 4, 3, 56, 41),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 1, 5, 25),
#   datetime.datetime(2005, 5, 31, 20, 4, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 2, 5, 34),
#   datetime.datetime(2005, 5, 30, 23, 3, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 2, 6, 37),
#   datetime.datetime(2005, 5, 29, 6, 57, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 2, 9, 19),
#   datetime.datetime(2005, 6, 5, 20, 34, 19),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 2, 40, 50),
#   datetime.datetime(2005, 6, 5, 3, 5, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 2, 51, 12),
#   datetime.datetime(2005, 5, 31, 6, 27, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 4, 4),
#   datetime.datetime(2005, 6, 3, 4, 58, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 8, 10),
#   datetime.datetime(2005, 5, 29, 7, 22, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 11, 47),
#   datetime.datetime(2005, 6, 4, 2, 19, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 17, 57),
#   datetime.datetime(2005, 5, 29, 6, 33, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 18, 2),
#   datetime.datetime(2005, 5, 30, 5, 32, 2),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 22, 33),
#   datetime.datetime(2005, 6, 3, 5, 6, 33),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 27, 37),
#   datetime.datetime(2005, 6, 4, 5, 47, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 32, 22),
#   datetime.datetime(2005, 5, 28, 22, 37, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 33, 20),
#   datetime.datetime(2005, 5, 31, 4, 23, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 3, 57, 28),
#   datetime.datetime(2005, 5, 31, 5, 20, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 4, 25, 33),
#   datetime.datetime(2005, 6, 6, 4, 18, 33),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 4, 27, 37),
#   datetime.datetime(2005, 5, 30, 7, 52, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 4, 28, 38),
#   datetime.datetime(2005, 6, 2, 8, 19, 38),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 4, 34, 17),
#   datetime.datetime(2005, 5, 30, 0, 35, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 5, 36, 58),
#   datetime.datetime(2005, 6, 2, 1, 50, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 6, 15, 25),
#   datetime.datetime(2005, 6, 6, 7, 51, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 6, 16, 32),
#   datetime.datetime(2005, 5, 31, 2, 48, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 6, 26, 16),
#   datetime.datetime(2005, 5, 30, 2, 2, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 6, 40, 25),
#   datetime.datetime(2005, 6, 6, 0, 47, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 6, 42, 13),
#   datetime.datetime(2005, 6, 3, 9, 5, 13),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 7, 3),
#   datetime.datetime(2005, 6, 6, 6, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 7, 16, 25),
#   datetime.datetime(2005, 6, 1, 8, 36, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 7, 35, 37),
#   datetime.datetime(2005, 6, 2, 9, 8, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 8, 38, 43),
#   datetime.datetime(2005, 6, 6, 13, 52, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 8, 54, 6),
#   datetime.datetime(2005, 6, 5, 5, 54, 6),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 9, 10, 49),
#   datetime.datetime(2005, 6, 6, 11, 32, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 9, 12, 9),
#   datetime.datetime(2005, 5, 29, 5, 7, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 9, 26, 31),
#   datetime.datetime(2005, 6, 1, 7, 28, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 9, 51, 39),
#   datetime.datetime(2005, 6, 5, 9, 35, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 9, 57, 36),
#   datetime.datetime(2005, 5, 31, 15, 44, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 10, 15, 4),
#   datetime.datetime(2005, 5, 30, 8, 32, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 10, 17, 41),
#   datetime.datetime(2005, 6, 5, 7, 56, 41),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 10, 35, 23),
#   datetime.datetime(2005, 6, 3, 6, 32, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 10, 44, 28),
#   datetime.datetime(2005, 6, 4, 11, 42, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 10, 56, 9),
#   datetime.datetime(2005, 6, 5, 15, 39, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 11, 15, 48),
#   datetime.datetime(2005, 6, 2, 9, 59, 48),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 11, 19, 23),
#   datetime.datetime(2005, 6, 2, 13, 51, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 11, 33, 46),
#   datetime.datetime(2005, 5, 29, 8, 33, 46),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 11, 49),
#   datetime.datetime(2005, 6, 1, 11, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 12, 3),
#   datetime.datetime(2005, 5, 29, 13, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 13, 6, 50),
#   datetime.datetime(2005, 6, 2, 9, 18, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 13, 21, 8),
#   datetime.datetime(2005, 5, 29, 16, 55, 8),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 13, 41, 56),
#   datetime.datetime(2005, 5, 30, 12, 0, 56),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 13, 59, 54),
#   datetime.datetime(2005, 6, 5, 15, 16, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 14, 0, 3),
#   datetime.datetime(2005, 5, 29, 17, 10, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 14, 8, 22),
#   datetime.datetime(2005, 6, 4, 10, 50, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 14, 27, 51),
#   datetime.datetime(2005, 5, 29, 13, 13, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 15, 27, 22),
#   datetime.datetime(2005, 6, 2, 20, 1, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 15, 45, 39),
#   datetime.datetime(2005, 6, 2, 9, 55, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 15, 50, 7),
#   datetime.datetime(2005, 6, 1, 19, 45, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 15, 54, 45),
#   datetime.datetime(2005, 6, 4, 20, 26, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 15, 58, 12),
#   datetime.datetime(2005, 5, 30, 21, 54, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 15, 58, 22),
#   datetime.datetime(2005, 6, 4, 10, 13, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 16, 1, 28),
#   datetime.datetime(2005, 5, 30, 11, 19, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 16, 13, 22),
#   datetime.datetime(2005, 6, 6, 20, 35, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 16, 35, 46),
#   datetime.datetime(2005, 6, 1, 14, 19, 46),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 17, 37, 50),
#   datetime.datetime(2005, 6, 3, 16, 4, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 17, 46, 57),
#   datetime.datetime(2005, 6, 6, 18, 24, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 17, 47, 58),
#   datetime.datetime(2005, 6, 4, 16, 32, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 18, 25, 2),
#   datetime.datetime(2005, 5, 29, 18, 22, 2),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 18, 43, 26),
#   datetime.datetime(2005, 5, 30, 13, 39, 26),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 18, 45, 47),
#   datetime.datetime(2005, 6, 4, 15, 24, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 18, 59, 12),
#   datetime.datetime(2005, 6, 4, 18, 6, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 19, 14, 9),
#   datetime.datetime(2005, 6, 5, 14, 1, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 19, 22, 52),
#   datetime.datetime(2005, 6, 1, 0, 10, 52),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 19, 35, 45),
#   datetime.datetime(2005, 6, 5, 16, 0, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 19, 45, 40),
#   datetime.datetime(2005, 5, 29, 21, 2, 40),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 19, 46, 50),
#   datetime.datetime(2005, 5, 30, 16, 29, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 20, 18, 24),
#   datetime.datetime(2005, 5, 30, 16, 19, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 20, 23, 9),
#   datetime.datetime(2005, 6, 1, 2, 11, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 20, 53, 31),
#   datetime.datetime(2005, 5, 30, 15, 26, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 21, 38, 39),
#   datetime.datetime(2005, 5, 29, 21, 37, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 21, 49, 2),
#   datetime.datetime(2005, 5, 31, 3, 7, 2),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 21, 54, 45),
#   datetime.datetime(2005, 5, 29, 22, 32, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 22, 3, 25),
#   datetime.datetime(2005, 6, 3, 3, 39, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 22, 7, 30),
#   datetime.datetime(2005, 6, 1, 23, 42, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 28, 23, 39, 44),
#   datetime.datetime(2005, 6, 1, 1, 42, 44),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 0, 9, 48),
#   datetime.datetime(2005, 6, 2, 4, 27, 48),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 0, 27, 10),
#   datetime.datetime(2005, 5, 30, 2, 29, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 0, 32, 9),
#   datetime.datetime(2005, 5, 31, 23, 53, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 0, 45, 24),
#   datetime.datetime(2005, 6, 2, 1, 30, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 0, 54, 53),
#   datetime.datetime(2005, 6, 6, 0, 45, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 1, 1, 26),
#   datetime.datetime(2005, 6, 7, 6, 21, 26),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 1, 49, 43),
#   datetime.datetime(2005, 6, 5, 6, 52, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 1, 50, 53),
#   datetime.datetime(2005, 6, 3, 2, 28, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 1, 59, 10),
#   datetime.datetime(2005, 6, 1, 2, 45, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 2, 10, 52),
#   datetime.datetime(2005, 6, 1, 21, 52, 52),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 2, 18, 54),
#   datetime.datetime(2005, 5, 30, 5, 54, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 2, 26, 27),
#   datetime.datetime(2005, 6, 3, 4, 59, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 2, 48, 52),
#   datetime.datetime(2005, 5, 30, 6, 21, 52),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 3, 5, 49),
#   datetime.datetime(2005, 6, 4, 22, 48, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 3, 18, 19),
#   datetime.datetime(2005, 5, 30, 2, 45, 19),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 3, 48, 1),
#   datetime.datetime(2005, 6, 6, 5, 21, 1),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 3, 48, 36),
#   datetime.datetime(2005, 6, 3, 5, 3, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 4, 10, 17),
#   datetime.datetime(2005, 6, 7, 7, 13, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 4, 22, 41),
#   datetime.datetime(2005, 6, 5, 9, 28, 41),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 4, 52, 23),
#   datetime.datetime(2005, 6, 2, 2, 27, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 5, 28, 47),
#   datetime.datetime(2005, 5, 31, 11, 24, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 5, 30, 31),
#   datetime.datetime(2005, 6, 6, 4, 51, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 5, 34, 44),
#   datetime.datetime(2005, 5, 30, 5, 50, 44),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 6, 8, 15),
#   datetime.datetime(2005, 5, 30, 7, 16, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 6, 12, 38),
#   datetime.datetime(2005, 6, 3, 7, 41, 38),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 7, 0, 59),
#   datetime.datetime(2005, 6, 6, 1, 17, 59),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 7, 25, 16),
#   datetime.datetime(2005, 5, 30, 5, 21, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 7, 35, 21),
#   datetime.datetime(2005, 6, 5, 9, 14, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 8, 8, 13),
#   datetime.datetime(2005, 6, 7, 13, 35, 13),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 8, 35, 49),
#   datetime.datetime(2005, 6, 4, 11, 55, 49),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 8, 36, 30),
#   datetime.datetime(2005, 6, 5, 11, 30, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 9, 22, 57),
#   datetime.datetime(2005, 6, 1, 9, 10, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 9, 26, 34),
#   datetime.datetime(2005, 6, 5, 7, 28, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 9, 27),
#   datetime.datetime(2005, 6, 3, 4, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 9, 41, 40),
#   datetime.datetime(2005, 5, 30, 13, 31, 40),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 9, 55, 43),
#   datetime.datetime(2005, 6, 2, 4, 54, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 10, 14, 15),
#   datetime.datetime(2005, 6, 4, 6, 30, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 10, 28, 45),
#   datetime.datetime(2005, 6, 4, 12, 50, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 10, 29, 47),
#   datetime.datetime(2005, 6, 7, 15, 27, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 11, 7, 25),
#   datetime.datetime(2005, 6, 2, 14, 16, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 11, 15, 51),
#   datetime.datetime(2005, 6, 6, 7, 48, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 11, 32, 15),
#   datetime.datetime(2005, 5, 31, 17, 31, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 11, 37, 35),
#   datetime.datetime(2005, 5, 31, 16, 47, 35),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 11, 38, 34),
#   datetime.datetime(2005, 6, 2, 17, 4, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 11, 47, 2),
#   datetime.datetime(2005, 6, 6, 7, 14, 2),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 12, 51, 44),
#   datetime.datetime(2005, 6, 1, 17, 43, 44),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 13, 8, 6),
#   datetime.datetime(2005, 6, 6, 8, 19, 6),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 13, 18, 5),
#   datetime.datetime(2005, 6, 7, 17, 22, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 13, 19, 43),
#   datetime.datetime(2005, 6, 1, 18, 51, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 13, 35, 35),
#   datetime.datetime(2005, 6, 3, 17, 33, 35),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 14, 9, 53),
#   datetime.datetime(2005, 6, 5, 20, 5, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 14, 17, 17),
#   datetime.datetime(2005, 6, 6, 16, 46, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 14, 18, 32),
#   datetime.datetime(2005, 6, 6, 20, 14, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 14, 23, 58),
#   datetime.datetime(2005, 5, 30, 17, 44, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 15, 8, 41),
#   datetime.datetime(2005, 5, 30, 15, 51, 41),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 16, 13, 55),
#   datetime.datetime(2005, 5, 31, 16, 40, 55),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 16, 17, 7),
#   datetime.datetime(2005, 6, 6, 18, 15, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 16, 30, 42),
#   datetime.datetime(2005, 6, 1, 19, 11, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 16, 32, 10),
#   datetime.datetime(2005, 5, 31, 18, 1, 10),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 16, 44, 11),
#   datetime.datetime(2005, 6, 5, 16, 11, 11),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 17, 12, 17),
#   datetime.datetime(2005, 6, 3, 16, 6, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 17, 24, 48),
#   datetime.datetime(2005, 6, 5, 12, 25, 48),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 17, 28, 12),
#   datetime.datetime(2005, 5, 30, 14, 59, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 18, 10, 24),
#   datetime.datetime(2005, 6, 6, 22, 53, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 20, 14, 34),
#   datetime.datetime(2005, 6, 5, 20, 56, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 20, 16, 12),
#   datetime.datetime(2005, 6, 7, 17, 47, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 20, 24, 28),
#   datetime.datetime(2005, 6, 3, 15, 32, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 20, 39, 14),
#   datetime.datetime(2005, 5, 31, 18, 24, 14),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 21, 31, 12),
#   datetime.datetime(2005, 6, 4, 22, 49, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 21, 36),
#   datetime.datetime(2005, 6, 7, 17, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 21, 39, 37),
#   datetime.datetime(2005, 5, 30, 22, 6, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 21, 45, 32),
#   datetime.datetime(2005, 5, 31, 19, 1, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 21, 56, 15),
#   datetime.datetime(2005, 6, 8, 3, 18, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 21, 58, 43),
#   datetime.datetime(2005, 6, 6, 0, 54, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 22, 14, 55),
#   datetime.datetime(2005, 5, 30, 17, 22, 55),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 22, 16, 42),
#   datetime.datetime(2005, 6, 6, 1, 38, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 22, 43, 55),
#   datetime.datetime(2005, 6, 1, 17, 43, 55),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 22, 50, 25),
#   datetime.datetime(2005, 6, 6, 2, 27, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 23, 21, 56),
#   datetime.datetime(2005, 6, 2, 18, 40, 56),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 29, 23, 37),
#   datetime.datetime(2005, 6, 2, 23, 38),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 0, 28, 12),
#   datetime.datetime(2005, 6, 8, 2, 43, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 0, 31, 17),
#   datetime.datetime(2005, 6, 2, 19, 14, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 0, 32, 4),
#   datetime.datetime(2005, 6, 1, 2, 21, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 0, 58, 20),
#   datetime.datetime(2005, 6, 1, 0, 38, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 1, 17, 25),
#   datetime.datetime(2005, 6, 7, 2, 0, 25),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 1, 19, 53),
#   datetime.datetime(2005, 6, 5, 23, 40, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 1, 23, 7),
#   datetime.datetime(2005, 6, 7, 1, 50, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 1, 35, 12),
#   datetime.datetime(2005, 5, 31, 1, 51, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 1, 35, 15),
#   datetime.datetime(2005, 6, 6, 7, 27, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 1, 36, 57),
#   datetime.datetime(2005, 6, 1, 22, 44, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 1, 43, 31),
#   datetime.datetime(2005, 6, 1, 2, 5, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 2, 1, 21),
#   datetime.datetime(2005, 6, 7, 3, 25, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 2, 10, 32),
#   datetime.datetime(2005, 6, 1, 4, 42, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 2, 45, 16),
#   datetime.datetime(2005, 6, 8, 7, 28, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 2, 48, 32),
#   datetime.datetime(2005, 6, 6, 5, 43, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 3, 9, 11),
#   datetime.datetime(2005, 6, 3, 21, 27, 11),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 3, 27, 17),
#   datetime.datetime(2005, 6, 6, 8, 28, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 3, 43, 54),
#   datetime.datetime(2005, 6, 8, 4, 28, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 3, 54, 43),
#   datetime.datetime(2005, 6, 1, 22, 59, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 4, 19, 55),
#   datetime.datetime(2005, 5, 31, 2, 28, 55),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 4, 25, 47),
#   datetime.datetime(2005, 6, 6, 4, 32, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 5, 3, 4),
#   datetime.datetime(2005, 6, 6, 10, 35, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 5, 36, 21),
#   datetime.datetime(2005, 6, 1, 9, 32, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 5, 30, 5, 48, 59),
# ...
#   datetime.datetime(2005, 6, 17, 16, 54, 44),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 17, 22, 33),
#   datetime.datetime(2005, 6, 21, 16, 52, 33),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 17, 32, 24),
#   datetime.datetime(2005, 6, 18, 13, 12, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 17, 39, 39),
#   datetime.datetime(2005, 6, 25, 13, 6, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 17, 51, 1),
#   datetime.datetime(2005, 6, 20, 17, 27, 1),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 18, 7, 48),
#   datetime.datetime(2005, 6, 22, 12, 39, 48),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 18, 12, 17),
#   datetime.datetime(2005, 6, 18, 16, 11, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 18, 12, 54),
#   datetime.datetime(2005, 6, 24, 19, 55, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 18, 46, 58),
#   datetime.datetime(2005, 6, 24, 16, 1, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 18, 52, 12),
#   datetime.datetime(2005, 6, 25, 13, 55, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 18, 55, 11),
#   datetime.datetime(2005, 6, 17, 20, 11, 11),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 19, 23, 23),
#   datetime.datetime(2005, 6, 18, 0, 57, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 19, 27, 12),
#   datetime.datetime(2005, 6, 24, 19, 25, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 19, 30, 54),
#   datetime.datetime(2005, 6, 19, 14, 24, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 19, 47, 18),
#   datetime.datetime(2005, 6, 22, 23, 10, 18),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 4, 28),
#   datetime.datetime(2005, 6, 23, 22, 30, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 4, 50),
#   datetime.datetime(2005, 6, 26, 0, 57, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 7, 27),
#   datetime.datetime(2005, 6, 19, 20, 55, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 8, 37),
#   datetime.datetime(2005, 6, 22, 1, 54, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 10, 43),
#   datetime.datetime(2005, 6, 20, 19, 12, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 13, 3),
#   datetime.datetime(2005, 6, 22, 22, 56, 3),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 17, 20),
#   datetime.datetime(2005, 6, 20, 23, 55, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 18, 46),
#   datetime.datetime(2005, 6, 20, 17, 12, 46),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 21, 53),
#   datetime.datetime(2005, 6, 18, 23, 18, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 23, 30),
#   datetime.datetime(2005, 6, 21, 20, 2, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 32, 47),
#   datetime.datetime(2005, 6, 21, 2, 3, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 36),
#   datetime.datetime(2005, 6, 17, 16, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 20, 59, 35),
#   datetime.datetime(2005, 6, 24, 15, 31, 35),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 0, 20),
#   datetime.datetime(2005, 6, 25, 20, 25, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 6),
#   datetime.datetime(2005, 6, 21, 21, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 11),
#   datetime.datetime(2005, 6, 24, 15, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 15, 22),
#   datetime.datetime(2005, 6, 23, 17, 0, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 20, 41),
#   datetime.datetime(2005, 6, 18, 2, 21, 41),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 32, 50),
#   datetime.datetime(2005, 6, 26, 1, 11, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 34, 50),
#   datetime.datetime(2005, 6, 20, 16, 50, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 43, 45),
#   datetime.datetime(2005, 6, 17, 21, 37, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 48, 16),
#   datetime.datetime(2005, 6, 22, 3, 9, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 21, 51, 4),
#   datetime.datetime(2005, 6, 18, 18, 12, 4),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 22, 14, 21),
#   datetime.datetime(2005, 6, 21, 16, 51, 21),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 22, 35, 20),
#   datetime.datetime(2005, 6, 19, 3, 9, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 22, 49, 8),
#   datetime.datetime(2005, 6, 22, 21, 8, 8),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 23, 5, 36),
#   datetime.datetime(2005, 6, 19, 4, 46, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 23, 16, 15),
#   datetime.datetime(2005, 6, 21, 21, 54, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 23, 20, 16),
#   datetime.datetime(2005, 6, 20, 2, 34, 16),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 23, 22, 22),
#   datetime.datetime(2005, 6, 23, 0, 33, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 23, 39, 34),
#   datetime.datetime(2005, 6, 21, 23, 36, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 23, 44, 13),
#   datetime.datetime(2005, 6, 22, 4, 9, 13),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 16, 23, 45, 59),
#   datetime.datetime(2005, 6, 26, 5, 31, 59),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 0, 5, 22),
#   datetime.datetime(2005, 6, 20, 21, 9, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 0, 31, 35),
#   datetime.datetime(2005, 6, 25, 5, 19, 35),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 0, 43, 57),
#   datetime.datetime(2005, 6, 23, 5, 49, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 0, 54, 58),
#   datetime.datetime(2005, 6, 20, 19, 29, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 1, 12, 58),
#   datetime.datetime(2005, 6, 21, 4, 49, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 1, 13, 38),
#   datetime.datetime(2005, 6, 18, 3, 13, 38),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 1, 17, 12),
#   datetime.datetime(2005, 6, 21, 22, 35, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 1, 17, 31),
#   datetime.datetime(2005, 6, 25, 2, 11, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 1, 29, 30),
#   datetime.datetime(2005, 6, 25, 20, 43, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 1, 49, 36),
#   datetime.datetime(2005, 6, 23, 21, 13, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 2, 3, 22),
#   datetime.datetime(2005, 6, 25, 4, 38, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 2, 8),
#   datetime.datetime(2005, 6, 19, 21, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 2, 38, 28),
#   datetime.datetime(2005, 6, 23, 4, 39, 28),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 2, 50, 51),
#   datetime.datetime(2005, 6, 18, 7, 21, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 2, 55, 32),
#   datetime.datetime(2005, 6, 21, 3, 44, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 2, 57, 34),
#   datetime.datetime(2005, 6, 19, 0, 0, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 3, 8, 59),
#   datetime.datetime(2005, 6, 19, 7, 16, 59),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 3, 9, 56),
#   datetime.datetime(2005, 6, 18, 1, 49, 56),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 3, 18, 51),
#   datetime.datetime(2005, 6, 18, 5, 46, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 3, 19, 20),
#   datetime.datetime(2005, 6, 21, 0, 19, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 3, 58, 36),
#   datetime.datetime(2005, 6, 22, 9, 28, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 5, 12),
#   datetime.datetime(2005, 6, 26, 4, 13, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 16, 44),
#   datetime.datetime(2005, 6, 24, 7, 20, 44),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 17, 33),
#   datetime.datetime(2005, 6, 20, 0, 6, 33),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 18, 48),
#   datetime.datetime(2005, 6, 26, 0, 7, 48),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 25, 12),
#   datetime.datetime(2005, 6, 26, 8, 44, 12),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 25, 46),
#   datetime.datetime(2005, 6, 26, 9, 37, 46),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 29, 15),
#   datetime.datetime(2005, 6, 26, 8, 39, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 29, 58),
#   datetime.datetime(2005, 6, 21, 5, 58, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 4, 51, 43),
#   datetime.datetime(2005, 6, 24, 9, 35, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 5, 8, 27),
#   datetime.datetime(2005, 6, 23, 9, 13, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 5, 10, 36),
#   datetime.datetime(2005, 6, 19, 3, 52, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 5, 11, 27),
#   datetime.datetime(2005, 6, 23, 23, 16, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 5, 19, 47),
#   datetime.datetime(2005, 6, 21, 3, 39, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 5, 36, 7),
#   datetime.datetime(2005, 6, 24, 1, 44, 7),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 5, 40, 52),
#   datetime.datetime(2005, 6, 23, 5, 58, 52),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 6, 0, 23),
#   datetime.datetime(2005, 6, 24, 4, 49, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 6, 13, 34),
#   datetime.datetime(2005, 6, 18, 1, 51, 34),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 6, 16, 47),
#   datetime.datetime(2005, 6, 21, 6, 3, 47),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 6, 48, 19),
#   datetime.datetime(2005, 6, 21, 3, 23, 19),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 6, 48, 31),
#   datetime.datetime(2005, 6, 26, 8, 17, 31),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 6, 51, 56),
#   datetime.datetime(2005, 6, 22, 8, 27, 56),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 6, 54, 42),
#   datetime.datetime(2005, 6, 26, 2, 0, 42),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 7, 14, 15),
#   datetime.datetime(2005, 6, 20, 5, 59, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 7, 42, 22),
#   datetime.datetime(2005, 6, 22, 11, 59, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 7, 42, 45),
#   datetime.datetime(2005, 6, 20, 7, 12, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 7, 43, 39),
#   datetime.datetime(2005, 6, 25, 2, 24, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 7, 49, 17),
#   datetime.datetime(2005, 6, 20, 3, 47, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 8, 2, 20),
#   datetime.datetime(2005, 6, 25, 10, 25, 20),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 8, 6, 53),
#   datetime.datetime(2005, 6, 21, 5, 0, 53),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 8, 19, 22),
#   datetime.datetime(2005, 6, 25, 8, 43, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 8, 40, 22),
#   datetime.datetime(2005, 6, 19, 10, 47, 22),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 8, 43, 32),
#   datetime.datetime(2005, 6, 21, 11, 8, 32),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 2, 58),
#   datetime.datetime(2005, 6, 20, 3, 7, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 8, 58),
#   datetime.datetime(2005, 6, 23, 14, 55, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 10, 9),
#   datetime.datetime(2005, 6, 21, 15, 8, 9),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 19, 45),
#   datetime.datetime(2005, 6, 20, 11, 19, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 19, 52),
#   datetime.datetime(2005, 6, 21, 3, 35, 52),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 26, 15),
#   datetime.datetime(2005, 6, 21, 10, 18, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 30, 5),
#   datetime.datetime(2005, 6, 21, 12, 10, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 45, 30),
#   datetime.datetime(2005, 6, 20, 10, 52, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 9, 48, 5),
#   datetime.datetime(2005, 6, 23, 14, 43, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 10, 12, 15),
#   datetime.datetime(2005, 6, 20, 13, 56, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 10, 22, 13),
#   datetime.datetime(2005, 6, 24, 5, 4, 13),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 10, 31, 37),
#   datetime.datetime(2005, 6, 22, 11, 17, 37),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 10, 40, 36),
#   datetime.datetime(2005, 6, 23, 14, 23, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 10, 47, 24),
#   datetime.datetime(2005, 6, 19, 5, 12, 24),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 10, 48, 44),
#   datetime.datetime(2005, 6, 24, 8, 11, 44),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 10, 49, 23),
#   datetime.datetime(2005, 6, 25, 10, 48, 23),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 11, 14),
#   datetime.datetime(2005, 6, 26, 16, 37, 14),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 17, 45),
#   datetime.datetime(2005, 6, 26, 9, 42, 45),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 19, 43),
#   datetime.datetime(2005, 6, 19, 14, 18, 43),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 24, 57),
#   datetime.datetime(2005, 6, 26, 9, 48, 57),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 30, 8),
#   datetime.datetime(2005, 6, 23, 8, 36, 8),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 32, 30),
#   datetime.datetime(2005, 6, 22, 13, 37, 30),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 44, 54),
#   datetime.datetime(2005, 6, 19, 10, 53, 54),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 47, 17),
#   datetime.datetime(2005, 6, 21, 7, 19, 17),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 48, 5),
#   datetime.datetime(2005, 6, 25, 13, 16, 5),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 54, 15),
#   datetime.datetime(2005, 6, 21, 5, 55, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 11, 57, 15),
#   datetime.datetime(2005, 6, 24, 17, 18, 15),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 12, 3, 1),
#   datetime.datetime(2005, 6, 24, 10, 4, 1),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 12, 18, 36),
#   datetime.datetime(2005, 6, 20, 12, 13, 36),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 12, 39, 50),
#   datetime.datetime(2005, 6, 19, 14, 59, 50),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 12, 44, 39),
#   datetime.datetime(2005, 6, 25, 12, 32, 39),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 12, 52, 58),
#   datetime.datetime(2005, 6, 23, 11, 7, 58),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 13, 0, 51),
#   datetime.datetime(2005, 6, 22, 7, 3, 51),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 13, 5, 38),
#   datetime.datetime(2005, 6, 21, 17, 19, 38),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 13, 6, 56),
#   datetime.datetime(2005, 6, 23, 13, 46, 56),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 13, 8, 8),
#   datetime.datetime(2005, 6, 23, 10, 54, 8),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 13, 10, 59),
#   datetime.datetime(2005, 6, 19, 18, 15, 59),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 13, 13, 27),
#   datetime.datetime(2005, 6, 19, 10, 44, 27),
#   'Mike',
#   'Hillyer'),
#  (datetime.datetime(2005, 6, 17, 13, 24, 7),
#   datetime.datetime(2005, 6, 18, 18, 18, 7),
#   'Mike',
#   'Hillyer'),
#  ...]

# %%
pd.DataFrame(result)
# Out:
#                         0                   1     2         3
# 0     2005-05-24 22:53:30 2005-05-26 22:04:30  Mike   Hillyer
# 1     2005-05-24 22:54:33 2005-05-28 19:40:33  Mike   Hillyer
# 2     2005-05-24 23:03:39 2005-06-01 22:12:39  Mike   Hillyer
# 3     2005-05-24 23:05:21 2005-06-02 04:33:21  Mike   Hillyer
# 4     2005-05-24 23:08:07 2005-05-27 01:32:07  Mike   Hillyer
# ...                   ...                 ...   ...       ...
# 16039 2005-08-23 22:20:26 2005-08-25 20:14:26   Jon  Stephens
# 16040 2005-08-23 22:21:03 2005-08-31 03:09:03   Jon  Stephens
# 16041 2005-08-23 22:26:47 2005-08-27 18:02:47   Jon  Stephens
# 16042 2005-08-23 22:42:48 2005-08-25 02:48:48   Jon  Stephens
# 16043 2005-08-23 22:50:12 2005-08-30 01:01:12   Jon  Stephens
#
# [16044 rows x 4 columns]

# %% [markdown]
# # Challenge 1 - Working with JSON files
# Import the pandas library.

# %%
# your code here
## already did

# %% [markdown]
# In the next cell, load the data in nasa.json in the data folder and load it into a pandas dataframe. Name the dataframe nasa.

# %%
# your code here
nasa=pd.read_json('nasa.json', orient='values')
nasa=nasa[['fall',
       'geolocation', 'id', 'mass', 'name', 'nametype', 'recclass', 'reclat',
       'reclong', 'year']]
nasa
# Out:
#      fall                                        geolocation     id      mass  \
# 0    Fell  {'type': 'Point', 'coordinates': [6.08333, 50....      1      21.0
# 1    Fell  {'type': 'Point', 'coordinates': [10.23333, 56...      2     720.0
# 2    Fell  {'type': 'Point', 'coordinates': [-113, 54.216...      6  107000.0
# 3    Fell  {'type': 'Point', 'coordinates': [-99.9, 16.88...     10    1914.0
# 4    Fell  {'type': 'Point', 'coordinates': [-64.95, -33....    370     780.0
# ..    ...                                                ...    ...       ...
# 995  Fell  {'type': 'Point', 'coordinates': [79.41667, 13...  24009     230.0
# 996  Fell  {'type': 'Point', 'coordinates': [-7.61123, 29...  54823    7000.0
# 997  Fell  {'type': 'Point', 'coordinates': [111.53333, -...  24011   20000.0
# 998  Fell  {'type': 'Point', 'coordinates': [106.58333, -...  24012   16500.0
# 999  Fell  {'type': 'Point', 'coordinates': [34.76667, 47...  24019     600.0
#
#           name nametype               recclass    reclat    reclong  \
# 0       Aachen    Valid                     L5  50.77500    6.08333
# 1       Aarhus    Valid                     H6  56.18333   10.23333
# 2         Abee    Valid                    EH4  54.21667 -113.00000
# 3     Acapulco    Valid            Acapulcoite  16.88333  -99.90000
# 4      Achiras    Valid                     L6 -33.16667  -64.95000
# ..         ...      ...                    ...       ...        ...
# 995   Tirupati    Valid                     H6  13.63333   79.41667
# 996    Tissint    Valid  Martian (shergottite)  29.48195   -7.61123
# 997      Tjabe    Valid                     H6  -7.08333  111.53333
# 998   Tjerebon    Valid                     L5  -6.66667  106.58333
# 999  Tomakovka    Valid                    LL6  47.85000   34.76667
#
#                         year
# 0    1880-01-01T00:00:00.000
# 1    1951-01-01T00:00:00.000
# 2    1952-01-01T00:00:00.000
# 3    1976-01-01T00:00:00.000
# 4    1902-01-01T00:00:00.000
# ..                       ...
# 995  1934-01-01T00:00:00.000
# 996  2011-01-01T00:00:00.000
# 997  1869-01-01T00:00:00.000
# 998  1922-01-01T00:00:00.000
# 999  1905-01-01T00:00:00.000
#
# [1000 rows x 10 columns]

# %% [markdown]
# Now that we have loaded the data, let's examine it using the head() function.

# %%
# your code here
nasa.head()
# Out:
#    fall                                        geolocation   id      mass  \
# 0  Fell  {'type': 'Point', 'coordinates': [6.08333, 50....    1      21.0
# 1  Fell  {'type': 'Point', 'coordinates': [10.23333, 56...    2     720.0
# 2  Fell  {'type': 'Point', 'coordinates': [-113, 54.216...    6  107000.0
# 3  Fell  {'type': 'Point', 'coordinates': [-99.9, 16.88...   10    1914.0
# 4  Fell  {'type': 'Point', 'coordinates': [-64.95, -33....  370     780.0
#
#        name nametype     recclass    reclat    reclong  \
# 0    Aachen    Valid           L5  50.77500    6.08333
# 1    Aarhus    Valid           H6  56.18333   10.23333
# 2      Abee    Valid          EH4  54.21667 -113.00000
# 3  Acapulco    Valid  Acapulcoite  16.88333  -99.90000
# 4   Achiras    Valid           L6 -33.16667  -64.95000
#
#                       year
# 0  1880-01-01T00:00:00.000
# 1  1951-01-01T00:00:00.000
# 2  1952-01-01T00:00:00.000
# 3  1976-01-01T00:00:00.000
# 4  1902-01-01T00:00:00.000

# %% [markdown]
# ####  The value_counts() function is commonly used in pandas to find the frequency of every value in a column.
#
# In the cell below, use the value_counts() function to determine the frequency of all types of asteroid landings by applying the function to the fall column.

# %%
# your code here
nasa['fall'].value_counts()
# Out:
# Fell     996
# Found      4
# Name: fall, dtype: int64

# %% [markdown]
# Finally, let's save the dataframe as a json file again. Save the dataframe using the orient=records argument and name the file nasa-output.json. Remember to save the file inside the data folder.

# %%
# your code here
nasa.to_json('nasa-output.json', orient='records')

# %% [markdown]
# # Challenge 2 - Working with CSV and Other Separated Files
#
# Import the pandas library
#
# csv files are more commonly used as dataframes. In the cell below, load the file from the URL provided using the `read_csv()` function in pandas. Starting version 0.19 of pandas, you can load a csv file into a dataframe directly from a URL without having to load the file first like we did with the JSON URL. The dataset we will be using contains informtaions about NASA shuttles.
#
# In the cell below, we define the column names and the URL of the data. Following this cell, read the tst file to a variable called `shuttle`. Since the file does not contain the column names, you must add them yourself using the column names declared in `cols` using the `names` argument. Additionally, a tst file is space separated, make sure you pass ` sep=' '` to the function.

# %%
#Your pandas import here:

# %%
# Run this code:

cols = ['time', 'rad_flow', 'fpv_close', 'fpv_open', 'high', 'bypass', 'bpv_close', 'bpv_open', 'class']
tst_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/shuttle/shuttle.tst'

# %%
# Your code here:
shuttle=pd.read_csv(tst_url, sep=' ',names=cols)
shuttle
# Out:
#     time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 55     0        81          0        -6    11      25         88        64
# 56     0        96          0        52    -4      40         44         4
# 50    -1        89         -7        50     0      39         40         2
# 53     9        79          0        42    -2      25         37        12
# 55     2        82          0        54    -6      26         28         2
# ..   ...       ...        ...       ...   ...     ...        ...       ...
# 80     0        84          0       -36   -29       4        120       116
# 55     0        81          0       -20    25      26        102        76
# 55     0        77          0        12   -22      22         65        42
# 37     0       103          0        18   -16      66         85        20
# 56     2        98          0        52     1      42         46         4
#
#     class
# 55      4
# 56      4
# 50      1
# 53      4
# 55      1
# ..    ...
# 80      5
# 55      4
# 55      4
# 37      1
# 56      4
#
# [14500 rows x 9 columns]

# %% [markdown]
# Let's verify that this worked by looking at the `head()` function.

# %%
shuttle.head()
# Out:
#     time  rad_flow  fpv_close  fpv_open  high  bypass  bpv_close  bpv_open  \
# 55     0        81          0        -6    11      25         88        64
# 56     0        96          0        52    -4      40         44         4
# 50    -1        89         -7        50     0      39         40         2
# 53     9        79          0        42    -2      25         37        12
# 55     2        82          0        54    -6      26         28         2
#
#     class
# 55      4
# 56      4
# 50      1
# 53      4
# 55      1

# %% [markdown]
# To make life easier for us, let's turn this dataframe into a comma separated file by saving it using the `to_csv()` function. Save `shuttle` into the file `shuttle.csv` and ensure the file is comma separated and that we are not saving the index column.

# %%
# Your code here:
shuttle.to_csv('shuttle.csv',sep=',', index=False)

# %% [markdown]
# # Challenge 3 - Working with Excel Files
#
# We can also use pandas to convert excel spreadsheets to dataframes. Let's use the `read_excel()` function. In this case, `astronauts.xls` is in the same folder that contains this notebook. Read this file into a variable called `astronaut`.
#
# Note: Make sure to install the `xlrd` library if it is not yet installed.

# %%
# Your code here:
astronaut=pd.read_excel('astronauts.xls')

# %% [markdown]
# Use the `head()` function to inspect the dataframe.

# %%
# Your code here:
astronaut.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active 1967-05-17  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired 1936-03-07   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired 1946-03-03     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired 1951-05-20  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired 1930-01-20  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
#           Graduate Major Military Rank         Military Branch  Space Flights  \
# 0                Geology           NaN                     NaN              2
# 1          Solar Physics           NaN                     NaN              1
# 2  Aerospace Engineering       Colonel       US Army (Retired)              2
# 3    Applied Mathematics       Colonel  US Air Force (Retired)              4
# 4           Astronautics       Colonel  US Air Force (Retired)              2
#
#    Space Flight (hr)  Space Walks  Space Walks (hr)  \
# 0               3307            2              13.0
# 1                190            0               0.0
# 2                334            0               0.0
# 3                814            4              29.0
# 4                289            2               8.0
#
#                                             Missions Death Date Death Mission
# 0             STS-119 (Discovery), ISS-31/32 (Soyuz)        NaT           NaN
# 1                              STS 51-F (Challenger)        NaT           NaN
# 2               STS-28 (Columbia), STS-43 (Atlantis)        NaT           NaN
# 3  STS-41 (Discovery), STS-49 (Endeavor), STS-61 ...        NaT           NaN
# 4                               Gemini 12, Apollo 11        NaT           NaN

# %% [markdown]
# Use the `value_counts()` function to find the most popular undergraduate major among all astronauts.

# %%
# Your code here:

astronaut['Undergraduate Major'].value_counts()
# Out:
# Physics                                  35
# Aerospace Engineering                    33
# Mechanical Engineering                   30
# Aeronautical Engineering                 28
# Electrical Engineering                   23
#                                          ..
# Astronomy                                 1
# Marine Engineering & Nautical Science     1
# Philosophy                                1
# Bioscience                                1
# Military Science                          1
# Name: Undergraduate Major, Length: 83, dtype: int64

# %% [markdown]
# Due to all the commas present in the cells of this file, let's save it as a tab separated csv file. In the cell below, save `astronaut` as a tab separated file using the `to_csv` function. Call the file `astronaut.csv` and remember to remove the index column.

# %%
# Your code here:
astronaut.to_csv('astronaut.csv', sep=',', index=False)

# %% [markdown]
# # Bonus Challenge - Fertility Dataset
#
# Visit the following [URL](https://archive.ics.uci.edu/ml/datasets/Fertility) and retrieve the dataset as well as the column headers. Determine the correct separator and read the file into a variable called `fertility`. Examine the dataframe using the `head()` function.

# %%
# Your code here:
